# %%
from GP import *
import matplotlib.pyplot as plt
from pyDOE import lhs
import autograd.numpy as np

# %%
def f(x):
    return x * np.sin(4.0*np.pi*x)

# %%
N_samples = 10
sigma_n = 0.1
d = 1

x = -0.5+(1+0.5)*lhs(d,N_samples)
xp = np.linspace(-0.5,1,100)

y = f(x)+sigma_n*np.random.randn(N_samples,d)
yp = f(xp)

ymean,ystd = y.mean(),y.std()
y = (y-ymean)/ystd

xmean,xstd = x.mean(),x.std()
x = (x-xmean)/xstd

xp = (xp-xmean)/xstd
yp = (yp-ymean)/ystd

GP_model = GP(x,y)
plt.scatter(x,y)
plt.plot(xp,yp)

# %% [markdown]
# # Draw prior samples

# %%
num_prior = 100
# guessed hyperparameters
hyp0 = np.log(np.ones((d+1,)))
sigma_n = np.array([-1])
hyp = np.concatenate([hyp0,sigma_n])

# number of test points for prior
test_num = 100
xtest = np.linspace(-0.5,1,test_num)[:,np.newaxis]
xtest = (xtest-xmean)/xstd

# find prior covariance
cov = GP_model.rbf_kernel(xtest,xtest,hyp0)
ytest = np.random.multivariate_normal(np.zeros((test_num,)),cov,size=num_prior)
for i in range(ytest.shape[0]):
    plt.plot(xtest,ytest[i])
plt.ylim(-4,4)
# Out:
# (-4, 4)

# %%
hyp_final = GP_model.train(hyp)
# Out:
# Log likelihood -3.4378174939935473
# Log likelihood -3.6084971918232975
# Log likelihood -4.07327422121859
# Log likelihood -4.265211525819822
# Log likelihood -4.440771224312449
# Log likelihood -4.644602350991677
# Log likelihood -4.730242817879063
# Log likelihood -4.746964567819616
# Log likelihood -4.858496693450254
# Log likelihood -4.895724576845495
# Log likelihood -4.906078053788181
# Log likelihood -4.9482484696180755
# Log likelihood -4.966716441676793
# Log likelihood -4.983230658815873
# Log likelihood -4.990864634874565
# Log likelihood -4.9951210215171065
# Log likelihood -4.997172048149469
# Log likelihood -4.9982815560607285
# Log likelihood -4.99881642894185
# Log likelihood -4.999084438826438
# Log likelihood -4.99915552051519
# Log likelihood -4.999256907212472
# Log likelihood -4.999312517920221
# Log likelihood -4.99933695619621
# Log likelihood -4.999337006099582
# Log likelihood -4.999350263316123
# Log likelihood -4.999356664306395
# Log likelihood -4.999359902764238
# Log likelihood -4.999361515959256
# Log likelihood -4.999362323527993
# Log likelihood -4.999362727151043

# %%
hyp_final
# Out:
# array([ 8.68952982e-03, -1.62243499e+00, -1.44727888e+01])

# %%
mu,cov = GP_model.predict(xp[:,np.newaxis])
post = np.random.multivariate_normal(mu[:,0],cov,size=10)

# %%
plt.plot(xp,yp)
plt.plot(xp,mu)

# %%
plt.scatter(x,y)
for i in range(post.shape[0]):
    plt.plot(xp,post[i])
